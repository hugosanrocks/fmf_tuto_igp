# %% [markdown]
# # Repaso de analisis de Fourier (dominio de las frequencias)

# %%
# importamos las librerias a usar
import numpy as np
import matplotlib.pyplot as plt

# %%
# tamaño de los vectores
n_muestras = 51

# eje del timepo
t = np.linspace(-2.*np.pi, 2.*np.pi, n_muestras)

# eje de la amplitud
x = np.zeros((n_muestras), dtype=float)

# hacemos la figura de la señal
fig1 = plt.figure(1)
ax1 = fig1.add_subplot(1,1,1)
ax1.plot(t, x, lw=0.5, marker='.', markersize=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo (s)')
# Out:
# Text(0.5, 0, 'Tiempo (s)')

# %%
# una señal se registra después de t>0
for i in range(len(t)):
    if t[i] > 0:
        x[i] = np.sin(t[i])

# hacemos la figura de la señal
fig1 = plt.figure(1)
ax1 = fig1.add_subplot(1,1,1)
ax1.plot(t, x, lw=0.5, marker='.', markersize=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo')
# Out:
# Text(0.5, 0, 'Tiempo')

# %%
# Esta señeal es sencilla, pero imaginemos que esta señal podría se la suma de muchas señales sencillas

# tamaño de los vectores
n_muestras = 124

# eje del timepo
t = np.linspace(-2.*np.pi, 2.*np.pi, n_muestras)
# eje de la amplitud
x = np.zeros((n_muestras), dtype=float)
x_sum = np.zeros((n_muestras), dtype=float)

# Diferentes periodos de la señal
periodos = [1., 2., 4., 6.]

# hacemos la figura de la señal
fig1 = plt.figure(1)

for p in range(len(periodos)):
    for i in range(len(t)):
        if t[i] > 0:
            x[i] = np.sin(t[i]*periodos[p])
            x_sum[i] = x_sum[i] + x[i]
    ax1 = fig1.add_subplot(len(periodos)+2, 1, p+1)
    ax1.plot(t, x, lw=0.5, marker='.', markersize=3, c='red')
    ax1.set_ylabel('Amplitud')
    #if p == len(periodos) + 1:
ax1 = fig1.add_subplot(len(periodos)+2, 1, len(periodos)+1)
ax1.plot(t, x_sum, lw=0.5, marker='.', markersize=3, c='red')    
ax1.set_xlabel('Tiempo')
# Out:
# Text(0.5, 0, 'Tiempo')

# %%
# Cada una de estas señales se puedes describir en el dominio de las frequencias
# es facil comprender la representación de cada una de ellas al entender cada
# cuanto intervalo de timepo estas se repiten

# tamaño de los vectores
n_muestras = 124

# eje del timepo
t = np.linspace(-2.*np.pi, 2.*np.pi, n_muestras)
# eje de la amplitud
x = np.zeros((n_muestras), dtype=float)

# una señal se registra después de t>0
for i in range(len(t)):
    if t[i] > 0:
        x[i] = np.sin(t[i]*periodos[0])

# hacemos la figura de la señal
fig1 = plt.figure(1)
ax1 = fig1.add_subplot(len(periodos)+2,2,1)
ax1.plot(t, x, lw=0.5, marker='.', markersize=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo')
# Out:
# Text(0.5, 0, 'Tiempo')

# %%
# Dominio de la frequencia
dt = t[1]-t[0]

# valores básicos del dominio de las frecuencias
freq_max = 1 / (2*dt)
duracion = 4*np.pi
freq_muestreo = 1 / (duracion)

# eje de las frecuencias
freq = np.linspace(-freq_max, freq_max, n_muestras)

# convertir a frecuencias
señal_en_freq = np.fft.fft(x, n_muestras)
espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras #factor de escala IMPORTANTE

fig1 = plt.figure(1)
ax1 = fig1.add_subplot(len(periodos)+2,2,1)
ax1.scatter(t, x, marker='.', s=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo')

ax1 = fig1.add_subplot(len(periodos)+2,2,2)
ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Frecuencia')
ax1.set_xlim([0, 2])
# Out:
# (0.0, 2.0)

# %%
1/6
# Out:
# 0.16666666666666666

# %%
# Diferentes periodos de la señal
periodos = [1., 2., 4, 6.]

# para sumar todas las señales
x_sum = np.zeros((n_muestras), dtype=float)


# preparamos la grafica
fig1 = plt.figure(1)

k = 0
# una señal se registra después de t>0
for p in range(len(periodos)):
    for i in range(len(t)):
        if t[i] > 0:
            x[i] = np.sin(t[i]*periodos[p])
            x_sum[i] = x_sum[i] + x[i]
    
    señal_en_freq = np.fft.fft(x, n_muestras)
    espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras

    ax1 = fig1.add_subplot(len(periodos)+2,2,(p+1)*2-1)
    ax1.scatter(t, x, marker='.', s=3, c='red')
    ax1.set_xlim([-2*np.pi, 2*np.pi])
    ax1.set_xticklabels([])
    ax1 = fig1.add_subplot(len(periodos)+2,2,(p+1)*2)
    ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
    ax1.set_xticklabels([])
    ax1.set_xlim([0, 2])
    k = 1

señal_en_freq = np.fft.fft(x_sum, n_muestras)
espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras

ax1 = fig1.add_subplot(len(periodos)+2,2,len(periodos)*2+1)
ax1.scatter(t, x_sum, marker='.', s=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo (s)')
ax1.set_xlim([-2*np.pi, 2*np.pi])

ax1 = fig1.add_subplot(len(periodos)+2,2,len(periodos)*2+2)
ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
#ax1.set_xticklabels([])
ax1.set_xlim([0, 2])
ax1.set_xlabel('Frecuencia [Hz]')
# Out:
# Text(0.5, 0, 'Frecuencia [Hz]')

# %%
# Diferentes periodos de la señal
periodos = [1., 1.5, 2., 2.5, 3, 3.5, 4., 10]

# para sumar todas las señales
x_sum = np.zeros((n_muestras), dtype=float)


# preparamos la grafica
fig1 = plt.figure(1)

k = 0
# una señal se registra después de t>0
for p in range(len(periodos)):
    for i in range(len(t)):
        if t[i] > 0:
            x[i] = np.sin(t[i]*periodos[p])
            x_sum[i] = x_sum[i] + x[i]
    
    señal_en_freq = np.fft.fft(x, n_muestras)
    espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras

    ax1 = fig1.add_subplot(len(periodos)+2,2,(p+1)*2-1)
    ax1.scatter(t, x, marker='.', s=3, c='red')
    ax1.set_xlim([-2*np.pi, 2*np.pi])
    ax1.set_xticklabels([])
    ax1 = fig1.add_subplot(len(periodos)+2,2,(p+1)*2)
    ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
    ax1.set_xticklabels([])
    ax1.set_xlim([0, 2])
    k = 1

señal_en_freq = np.fft.fft(x_sum, n_muestras)
espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras

ax1 = fig1.add_subplot(len(periodos)+2,2,len(periodos)*2+1)
ax1.scatter(t, x_sum, marker='.', s=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo (s)')
ax1.set_xlim([-2*np.pi, 2*np.pi])

ax1 = fig1.add_subplot(len(periodos)+2,2,len(periodos)*2+2)
ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
ax1.set_xlim([0, 2])
ax1.set_xlabel('Frecuencia [Hz]')
# Out:
# Text(0.5, 0, 'Frecuencia [Hz]')

# %%
# Diferentes periodos de la señal
periodos = [1., 7.]

# Diferentes coeficientes, diferente energia viaja en diferentes frecuencias
coeficientes = [1., 0.5]

# para sumar todas las señales
x_sum = np.zeros((n_muestras), dtype=float)


# preparamos la grafica
fig1 = plt.figure(1)

k = 0
# una señal se registra después de t>0
for p in range(len(periodos)):
    for i in range(len(t)):
        if t[i] > 0:
            x[i] = coeficientes[p]*np.sin(t[i]*periodos[p])
            x_sum[i] = x_sum[i] + x[i]
    
    señal_en_freq = np.fft.fft(x, n_muestras)
    espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras

    ax1 = fig1.add_subplot(len(periodos)+2,2,(p+1)*2-1)
    ax1.scatter(t, x, marker='.', s=3, c='red')
    ax1.set_xlim([-2*np.pi, 2*np.pi])
    ax1.set_ylim([-1, 1])
    ax1.set_xticklabels([])
    ax1 = fig1.add_subplot(len(periodos)+2,2,(p+1)*2)
    ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
    ax1.set_xticklabels([])
    ax1.set_xlim([0, 2])
    ax1.set_ylim([0, 0.26])
    k = 1

señal_en_freq = np.fft.fft(x_sum, n_muestras)
espectro_amp = np.abs(np.fft.fftshift(señal_en_freq)) / n_muestras

ax1 = fig1.add_subplot(len(periodos)+2,2,len(periodos)*2+1)
ax1.scatter(t, x_sum, marker='.', s=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo (s)')
ax1.set_xlim([-2*np.pi, 2*np.pi])

ax1 = fig1.add_subplot(len(periodos)+2,2,len(periodos)*2+2)
ax1.scatter(freq, espectro_amp, marker='.', s=3, c='red')
ax1.set_xlim([0, 2])
ax1.set_xlabel('Frecuencia [Hz]')
# Out:
# Text(0.5, 0, 'Frecuencia [Hz]')

# %%
import obspy as obs

# Pasamos a obspy la segnal sumada
senal = x_sum
t = obs.Trace(senal)
t.stats.sampling_rate = 1/dt

#filtramos la segnal
bandpass = 'bandpass'
bandpass_fmin = 0.7
bandpass_fmax = 2.
t.filter(bandpass, freqmin=bandpass_fmin, freqmax=bandpass_fmax, zerophase=True)
t.plot()

# %%
# importo librerias
import obspy as obs
from obspy import UTCDateTime

# leer el archivo de todo un dia
s = obs.read('PE.LAGN..BHZ.D.2022.146')

print(len(s[0].data))

# declaro timempos para graficar
t1 = UTCDateTime("2022-05-26T12:02:00.000")
t2 = UTCDateTime("2022-05-26T12:05:20.000")
#s.plot(starttime=t1, endtime=t2)

# 50 muestras por segundo
# 1 seg tiene 50 muestras
# 1 min tiene 60 segundos
# 1 hora tiene 60 minutos

#            12:00         12:02    12:02:50
muestra_1 = 12*60*60*50 + 2*60*50 + 50*50
#            12:02:50    12:03
muestra_2 = muestra_1 + 10*50

# cortar el registro de muestra 1 a muestra 2



# lleno con ceros
# el arreglo debe tener el numero de muestras cercanas a potencia de dos por arriba
# la senal tine 500 muestras, entonces 512 es lo mas cercano 2^9
n_muestras = 512

data = np.zeros((512), dtype=float)


# guardar mi senal en el arreglo que declare
# corto mi senal de interes
data[0:500] = s[0].data[muestra_1:muestra_2]
#plt.plot(data)

# traza de obspy ... convierto vector de numpy a traza de obspy
t = obs.Trace(data)
t.taper(max_percentage=0.08, type='hann')
data = t.data
#plt.plot(data, c='red')

# creo vector de tiempo
dt = 1 / 50
t = np.linspace(0, 10+12*dt, 512)

# creamos vector de frecuencias
f_max = 1 / (2*dt)
duracion = t[-1]   # ultimo valor del timepo
f_muestreo = 1 / duracion
freq = np.linspace(-f_max, f_max, n_muestras)

# hacemos transformada de Fourier
senal_fft = np.fft.fft(data, n_muestras)
espectro_senal = np.abs(np.fft.fftshift(senal_fft))

fig1 = plt.figure(1)
ax1 = fig1.add_subplot(2,1,1)
ax1.semilogx(freq, espectro_senal, c='red')
ax1.set_xlim([0.8, 25])
ax1.set_xlabel('frecuencia')
ax1.set_ylabel('amplitud')
# Out:
# 4320000
# Text(0, 0.5, 'amplitud')

# %%
s
# Out:
# 1 Trace(s) in Stream:
# PE.LAGN..BHZ | 2022-05-26T00:00:00.000000Z - 2022-05-26T23:59:59.980000Z | 50.0 Hz, 4320000 samples

# %%
import obspy as obs
from obspy import UTCDateTime
s = obs.read('PE.LAGN..BHZ.D.2022.146')
t1 = UTCDateTime("2022-05-26T12:02:00.000")
t2 = UTCDateTime("2022-05-26T12:05:20.000")
#s.plot(starttime=t1, endtime=t2)

muestra_1 = 12*60*60*50 + 2*60*50 + 50*50
muestra_2 = muestra_1 + 10*50

data = np.zeros((512), dtype=float)
data[0:500] = s[0].data[muestra_1:muestra_2]
tr = obs.Trace(data)
tr.taper(max_percentage=0.15, type='hann')
data = tr.data[0:512]

n_muestras = 512

dt = 1/50    # 60 min * 60 sec * 20 muestras  = 72000
t = np.linspace(0, (n_muestras-1)*dt, n_muestras)


# valores básicos del dominio de las frecuencias
freq_max = 1 / (2*dt)
freq_muestreo = 1 / (t[-1])

# eje de las frecuencias
freq = np.linspace(-freq_max, freq_max, n_muestras)


senal_en_freq = np.fft.fft(data, n_muestras)
espectro_amp = np.abs(np.fft.fftshift(senal_en_freq)) / n_muestras



fig1 = plt.figure(1)
ax1 = fig1.add_subplot(4,2,1)
ax1.plot(t, data, marker='.', c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo')

ax1 = fig1.add_subplot(4,2,2)
ax1.plot(freq, espectro_amp, marker='.', lw=0.01, c='red')
#ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Frecuencia')
#ax1.set_xlim([0, 100])


print(len(data))
# Out:
# 512

# %%
# Entonces ahora hagamoslo para un terremoto de verdad

from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("IRIS")

# The following example illustrates how to request and 
# plot 60 minutes of the "BHZ" channel of station Albuquerque, 
# New Mexico ("ANMO") of the Global Seismograph Network 
# ("IU") for an seismic event around 2010-02-27 06:45 (UTC). 
# Results are returned as a Stream object. See the get_waveforms_bulk() 
# method for information on how to send multiple requests simultaneously to avoid unnecessary network overhead.

t = UTCDateTime("2010-02-27T07:05:00.000")
#st = client.get_waveforms("IU", "ANMO", "00", "BHZ", t, t + 1000)
st.taper(max_percentage=0.15, type='hann')

#t = UTCDateTime("2010-02-27T07:05:00.000")
#st.plot( starttime=t, endtime=t+1000)

# mis muestras son n_muestras = 72000
n_muestras_orig = 20000

n_muestras = 512  # 2^15

# dt = t[1]-t[2]
dt = 1/20    # 60 min * 60 sec * 20 muestras  = 72000
n1 = 2500
senal = np.zeros((n_muestras), dtype=float)
senal[0:n_muestras] = st[0].data[n1:n1+n_muestras]
t = np.linspace(0, (n_muestras-1)*dt, n_muestras)

# valores básicos del dominio de las frecuencias
freq_max = 1 / (2*dt)
freq_muestreo = 1 / (t[-1])

# eje de las frecuencias
freq = np.linspace(-freq_max, freq_max, n_muestras)


senal_en_freq = np.fft.fft(senal, n_muestras)
espectro_amp = np.abs(np.fft.fftshift(senal_en_freq)) / n_muestras


fig1 = plt.figure(1)
ax1 = fig1.add_subplot(len(periodos)+2,2,1)
ax1.plot(t, senal, marker='.', c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo')

ax1 = fig1.add_subplot(len(periodos)+2,2,2)
ax1.plot(freq, espectro_amp, marker='.', lw=0.01, c='red')
#ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Frecuencia')
#ax1.set_xlim([0, 100])
# Out:
# Text(0.5, 0, 'Frecuencia')

# %%
512/20
# Out:
# 25.6

# %%
# para suavizar los espectros
import konno_ohmachi as ko

# suavizamos el espectro
espectro_suave = ko.faster_konno_ohmachi(espectro_amp, freq, n_cores=None)

# preparamos la grafica
fig1 = plt.figure(1)

ax1 = fig1.add_subplot(4,2,1)
ax1.scatter(t, x_sum, marker='.', s=3, c='red')
ax1.set_ylabel('Amplitud')
ax1.set_xlabel('Tiempo (s)')
ax1.set_xlim([-2*np.pi, 2*np.pi])

ax1 = fig1.add_subplot(4,2,4)
ax1.scatter(freq, espectro_suave, marker='.', s=3, c='red')
ax1.set_xlim([0, 2])
ax1.set_xlabel('Frecuencia [Hz]')


ax1 = fig1.add_subplot(4,2,4)
ax1.scatter(freq, espectro_suave, marker='.', s=3, c='red')
ax1.set_xlim([0, 2])
ax1.set_xlabel('Frecuencia [Hz]')
# Out:
# Text(0.5, 0, 'Frecuencia [Hz]')

# %%
import obspy as obs
from obspy import UTCDateTime
s = obs.read('PE.LAGN..BHZ.D.2022.146')
t1 = UTCDateTime("2022-05-26T12:02:00.000")
t2 = UTCDateTime("2022-05-26T12:05:20.000")
#s.plot(starttime=t1, endtime=t2)

muestra_1 = 12*60*60*50 + 2*60*50 + 50*50
muestra_2 = muestra_1 + 10*50

data = np.zeros((512), dtype=float)
data[0:500] = s[0].data[muestra_1:muestra_2]

plt.plot(data)
print(len(s[0].data))
# Out:
# 4320000

# %%
4320000/(24*60*60)
# Out:
# 50.0
